# %% [markdown]
# # 03 - Evaluation
#
# Model evaluation: precision, recall, F1, confusion matrix, ROC-AUC.
#
# Targets: Recall >= 99.57%, Precision >= 98.66%

# %%
# TODO: Evaluation notebook
# - Load test split and model
# - Run predictions
# - Classification report
# - Confusion matrix visualization
# - ROC curve
# - Error analysis (BEC/spear-phishing weaknesses)
