# %% [markdown]
# # 02 - Training
#
# Fine-tuning DistilBERT for email phishing classification.
#
# Config: epochs=3, batch_size=8, lr=5e-5, max_seq_length=256

# %%
# TODO: Interactive training notebook
# - Load preprocessed data
# - Tokenize with DistilBERT tokenizer
# - Fine-tune with Trainer API
# - Track with MLflow
# - Save best model
