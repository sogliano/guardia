# %% [markdown]
# # 01 - Data Exploration
#
# Exploratory analysis of the email phishing dataset (1,374 samples).

# %%
# TODO: Load and explore dataset
# - Class distribution
# - Text length statistics
# - Common keywords
# - Sender domain analysis
